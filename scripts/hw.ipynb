# %%
import scripts.jupyter_config as jupyter_config
from src import sample_data_preperation
sample_data_preperation.main()
# Out:
# 2026-09-01 15:22:31.460 | INFO     | src.config:<module>:11 - PROJ_ROOT path is: /Users/gordon/Documents/GitHub/ECON138-Final-Paper
# 2026-09-01 15:22:31.596 | INFO     | src.sample_data_preperation:main:20 - Processing fred dataset...
# 2026-09-01 15:22:31.613 | INFO     | src.sample_data_preperation:main:24 - Processing yfinance dataset...
# 2026-09-01 15:22:32.020 | INFO     | src.sample_data_preperation:main:29 - Processing model dataset...
# 2026-09-01 15:22:32.023 | SUCCESS  | src.sample_data_preperation:main:34 - Processing dataset complete.

# %%
# %%R
# source("../scripts/init.R")
# source("../scripts/read_data.R")
# source("../scripts/stock_ts.R")
# Out:
# Loading required package: pacman

# %%
# %%R
# data("elecdaily")
# autoplot(elecdaily[,"Demand"])

# %%
# %%R
# autoplot(elecdaily[,"WorkDay"])

# %%
# %%R
# autoplot(elecdaily[,"Temperature"])

# %%
# %%R
# plot(elecdaily[,"Demand"],elecdaily[,"Temperature"])

# %%
# %%R
# model <- lm(Demand ~ Temperature, data = elecdaily)

# %%
# %%R
# plot(model)

# %%
# %%R
# daily20 <- head(elecdaily, 20)
# model2 <- lm(Demand ~ Temperature, data=daily20)
# print(model2)
# plot(model2)
# Out:
# Call:
# lm(formula = Demand ~ Temperature, data = daily20)
#
# Coefficients:
# (Intercept)  Temperature
#      39.212        6.757

# %%
# %%R
# forecast(model2, newdata = data.frame(Temperature = c(15, 35)))
# Out:
#   Point Forecast    Lo 80    Hi 80     Lo 95    Hi 95
# 1       140.5701 108.6810 172.4591  90.21166 190.9285
# 2       275.7146 245.2278 306.2014 227.57056 323.8586
